# %%
pip install pikepdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tabula-py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tabula as tb
import pandas as pd
import pikepdf

# %% [markdown]
# # -->> Bank Statement of Aryan Dalwadi

# %%
pdf_path = "D://bank statement.pdf"

# %%
df = tb.read_pdf("D://bank statement.pdf",stream=True,pages='all')

# %%
df
# Out:
# [      Tran Id   Tran Date                       Remarks Amount (Rs.)  \
#  0   S50143038  30/01/2022    UPIAR/203036183230/DR/DREA   15.00 (Dr)
#  1         NaN         NaN        M11/YESB/DREAM11ONLINE          NaN
#  2         NaN         NaN                            @y          NaN
#  3   S46872325  30/01/2022    UPIAR/203013423691/DR/DAVE  950.00 (Dr)
#  4         NaN         NaN       VIV/KKBK/vikidave06@oks          NaN
#  5   S46709981  30/01/2022   UPIAB/203007413421/CR/PATEL  200.00 (Cr)
#  6         NaN         NaN        MA/HDFC/sonusoni024024          NaN
#  7   S46535807  30/01/2022  UPIAB/203041151091/CR/PRAJAP  130.00 (Cr)
#  8         NaN         NaN        AT/UBIN/9574471213@pay          NaN
#  9   S45889789  30/01/2022   UPIAB/203039108853/CR/AKASH  150.00 (Cr)
#  10        NaN         NaN        KI/BKID/7878144491@pay          NaN
#  11  S45074785  30/01/2022      UPIAB/203036598207/CR/OM   70.00 (Cr)
# ...

# %%
#tb.convert_into(pdf_path,"bank_stat1.csv",output_format="csv",pages='all')

# %%
test2= pd.read_csv("C://Users//utsav//bank_stat1.csv")

# %%
test2
# Out:
#                                                Tran Id   Tran Date  \
# 0                                            S50143038  30/01/2022
# 1                                            S46872325  30/01/2022
# 2                                            S46709981  30/01/2022
# 3                                            S46535807  30/01/2022
# 4                                            S45889789  30/01/2022
# ..                                                 ...         ...
# 151                                            Tran Id   Tran Date
# 152                                          S41681396  03/11/2021
# 153                                          S90499858  01/11/2021
# 154  Statement Legends :\rNEFT : National Electroni...         NaN
# 155  This is system generated statement and does no...         NaN
#
#                                                Remarks  Amount (Rs.)  \
# 0    UPIAR/203036183230/DR/DREA\rM11/YESB/DREAM11ON...    15.00 (Dr)
# ...

# %%
test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tran Id        156 non-null    object
#  1   Tran Date      154 non-null    object
#  2   Remarks        154 non-null    object
#  3   Amount (Rs.)   154 non-null    object
#  4   Balance (Rs.)  154 non-null    object
# dtypes: object(5)
# memory usage: 6.2+ KB

# %%
test2['Amount (Rs.)']=test2['Amount (Rs.)'].astype('str')

# %%
idx =[]
for i in range(test2.shape[0]):
    if "Amount (Rs.)" in test2.iloc[i,3]:
        idx.append(i)

# %%
idx
# Out:
# [10, 33, 55, 79, 103, 127, 151]

# %%
test2 = test2.drop(idx,axis=0)
test2
# Out:
#                                                Tran Id   Tran Date  \
# 0                                            S50143038  30/01/2022
# 1                                            S46872325  30/01/2022
# 2                                            S46709981  30/01/2022
# 3                                            S46535807  30/01/2022
# 4                                            S45889789  30/01/2022
# ..                                                 ...         ...
# 150                                          S45289576  04/11/2021
# 152                                          S41681396  03/11/2021
# 153                                          S90499858  01/11/2021
# 154  Statement Legends :\rNEFT : National Electroni...         NaN
# 155  This is system generated statement and does no...         NaN
#
#                                                Remarks Amount (Rs.)  \
# 0    UPIAR/203036183230/DR/DREA\rM11/YESB/DREAM11ON...   15.00 (Dr)
# ...

# %%
test2.shape
# Out:
# (149, 5)

# %%
test2.drop([154,155],axis=0,inplace=True)

# %%
test2.shape
# Out:
# (147, 5)

# %%
cr_list,db_list =[],[]

# %%
for i in range(test2.shape[0]):
    if "Dr" in test2.iloc[i,3]:
        db_list.append(test2.iloc[i,3])
        cr_list.append("NaN")
    else:
        db_list.append("NaN")
        cr_list.append(test2.iloc[i,3])

# %%
print(len(db_list))
print(len(cr_list))
print(db_list)
print(cr_list)
# Out:
# 147
# 147
# ...

# %%
db_list2,cr_list2=[],[]

for i in db_list:
    if "Dr" in i:
        db_list2.append(i[:-5])
    else:
        db_list2.append(i)

for i in cr_list:
    if "Cr" in i:
        cr_list2.append(i[:-5])
    else:
        cr_list2.append(i)

# %%
db_list2
# Out:
# ['15.00',
#  '950.00',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  '340.00',
#  'NaN',
#  'NaN',
#  'NaN',
#  '15.00',
#  '350.00',
#  '14.00',
#  '99.00',
#  'NaN',
#  '11.00',
#  '140.00',
#  '66.00',
#  '15.00',
#  'NaN',
#  '389.00',
#  'NaN',
#  '1500.00',
#  'NaN',
#  '150.00',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  '600.00',
#  '200.00',
#  '59.00',
#  '59.00',
#  '60.00',
#  '1.00',
#  '140.00',
#  'NaN',
#  '59.00',
#  'NaN',
#  '8.00',
#  'NaN',
#  'NaN',
#  '180.00',
#  '1970.00',
#  'NaN',
#  '400.00',
#  '59.00',
#  'NaN',
#  'NaN',
#  'NaN',
#  '39.00',
#  '29.00',
#  'NaN',
#  '1076.60',
#  'NaN',
#  'NaN',
#  '50.00',
#  '100.00',
#  '19.00',
#  '40.00',
#  '20.00',
#  'NaN',
#  '150.00',
#  '490.00',
#  '487.26',
#  'NaN',
#  'NaN',
#  '200.00',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  '100.00',
#  'NaN',
#  '50.00',
#  '50.00',
#  '50.00',
#  '500.00',
#  'NaN',
#  '10.00',
#  '99.00',
#  'NaN',
#  '185.40',
#  '1300.00',
#  'NaN',
#  'NaN',
# ...

# %%
cr_list2
# Out:
# ['NaN',
#  'NaN',
#  '200.00',
#  '130.00',
#  '150.00',
#  '70.00',
#  '68.00',
#  'NaN',
#  '150.00',
#  '150.00',
#  '150.00',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  '2628.50',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  '150.00',
#  'NaN',
#  '400.00',
#  'NaN',
#  '500.00',
#  'NaN',
#  '180.00',
#  '200.00',
#  '200.00',
#  '170.00',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  '200.00',
#  'NaN',
#  '40.00',
#  'NaN',
#  '40.00',
#  '240.00',
#  'NaN',
#  'NaN',
#  '1060.00',
#  'NaN',
#  'NaN',
#  '2000.00',
#  '141.00',
#  '22.00',
#  'NaN',
#  'NaN',
#  '532.28',
#  'NaN',
#  '100.00',
#  '1000.00',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  '150.00',
#  'NaN',
#  'NaN',
#  'NaN',
#  '490.00',
#  '490.00',
#  'NaN',
#  '100.00',
#  '30.00',
#  '80.00',
#  '90.00',
#  'NaN',
#  '150.00',
#  'NaN',
#  'NaN',
#  'NaN',
#  'NaN',
#  '500.00',
#  'NaN',
#  'NaN',
#  '6.00',
#  'NaN',
#  'NaN',
#  '1050.00',
#  '599.00',
#  'NaN',
# ...

# %%
x = test2['Balance (Rs.)']

# %%
df2 = pd.DataFrame({"Tran ID":test2['Tran Id'],"Debit amount":db_list2,"Credit amount":cr_list2,"Balance":x })

# %%
df2
# Out:
#        Tran ID Debit amount Credit amount  Balance
# 0    S50143038        15.00           NaN  1934.28
# 1    S46872325       950.00           NaN  1949.28
# 2    S46709981          NaN        200.00  2899.28
# 3    S46535807          NaN        130.00  2699.28
# 4    S45889789          NaN        150.00  2569.28
# ..         ...          ...           ...      ...
# 148  S45877639       350.00           NaN   775.76
# 149  S45866273          NaN        150.00  1125.76
# 150  S45289576          NaN        200.00   975.76
# 152  S41681396          NaN        751.00   775.76
# 153  S90499858       220.00           NaN    24.76
#
# [147 rows x 4 columns]

# %%
#df2.to_csv("bs.csv",index=0)

# %%
pd.read_csv("bs.csv")
# Out:
#        Tran ID  Debit amount  Credit amount  Balance   Tran Date
# 0    S50143038          15.0            NaN  1934.28  30/01/2022
# 1    S46872325         950.0            NaN  1949.28  30/01/2022
# 2    S46709981           NaN          200.0  2899.28  30/01/2022
# 3    S46535807           NaN          130.0  2699.28  30/01/2022
# 4    S45889789           NaN          150.0  2569.28  30/01/2022
# ..         ...           ...            ...      ...         ...
# 142  S45877639         350.0            NaN   775.76  04/11/2021
# 143  S45866273           NaN          150.0  1125.76  04/11/2021
# 144  S45289576           NaN          200.0   975.76  04/11/2021
# 145  S41681396           NaN          751.0   775.76  03/11/2021
# 146  S90499858         220.0            NaN    24.76  01/11/2021
#
# [147 rows x 5 columns]

# %%
test2['Tran Date']
# Out:
# 0      30/01/2022
# 1      30/01/2022
# 2      30/01/2022
# 3      30/01/2022
# 4      30/01/2022
#           ...
# 148    04/11/2021
# 149    04/11/2021
# 150    04/11/2021
# 152    03/11/2021
# 153    01/11/2021
# Name: Tran Date, Length: 147, dtype: object

# %%
df2['Tran Date'] = test2['Tran Date']

# %%
df2
# Out:
#        Tran ID Debit amount Credit amount  Balance   Tran Date
# 0    S50143038        15.00           NaN  1934.28  30/01/2022
# 1    S46872325       950.00           NaN  1949.28  30/01/2022
# 2    S46709981          NaN        200.00  2899.28  30/01/2022
# 3    S46535807          NaN        130.00  2699.28  30/01/2022
# 4    S45889789          NaN        150.00  2569.28  30/01/2022
# ..         ...          ...           ...      ...         ...
# 148  S45877639       350.00           NaN   775.76  04/11/2021
# 149  S45866273          NaN        150.00  1125.76  04/11/2021
# 150  S45289576          NaN        200.00   975.76  04/11/2021
# 152  S41681396          NaN        751.00   775.76  03/11/2021
# 153  S90499858       220.00           NaN    24.76  01/11/2021
#
# [147 rows x 5 columns]

# %%
#df2.to_csv("bs.csv",index=0)

# %%
df3=pd.read_csv("bs.csv")
df3
# Out:
#        Tran ID  Debit amount  Credit amount  Balance   Tran Date
# 0    S50143038          15.0            NaN  1934.28  30/01/2022
# 1    S46872325         950.0            NaN  1949.28  30/01/2022
# 2    S46709981           NaN          200.0  2899.28  30/01/2022
# 3    S46535807           NaN          130.0  2699.28  30/01/2022
# 4    S45889789           NaN          150.0  2569.28  30/01/2022
# ..         ...           ...            ...      ...         ...
# 142  S45877639         350.0            NaN   775.76  04/11/2021
# 143  S45866273           NaN          150.0  1125.76  04/11/2021
# 144  S45289576           NaN          200.0   975.76  04/11/2021
# 145  S41681396           NaN          751.0   775.76  03/11/2021
# 146  S90499858         220.0            NaN    24.76  01/11/2021
#
# [147 rows x 5 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tran ID        147 non-null    object
#  1   Debit amount   86 non-null     float64
#  2   Credit amount  61 non-null     float64
#  3   Balance        147 non-null    float64
#  4   Tran Date      147 non-null    object
# dtypes: float64(3), object(2)
# memory usage: 5.9+ KB

# %%
df3["Tran Date"] = pd.to_datetime(df3['Tran Date'],dayfirst=True)

# %%
df3["Tran Date"]
# Out:
# 0     2022-01-30
# 1     2022-01-30
# 2     2022-01-30
# 3     2022-01-30
# 4     2022-01-30
#          ...
# 142   2021-11-04
# 143   2021-11-04
# 144   2021-11-04
# 145   2021-11-03
# 146   2021-11-01
# Name: Tran Date, Length: 147, dtype: datetime64[ns]

# %%
df3[((df3["Tran Date"].dt.month==1) | (df3["Tran Date"].dt.month==12)) & (df3['Debit amount']>1000)]
# Out:
#        Tran ID  Debit amount  Credit amount   Balance  Tran Date
# 23   S48541898        1500.0            NaN     91.78 2022-01-16
# 44   S87434111        1970.0            NaN   1337.78 2022-01-08
# 54   S62374883        1076.6            NaN     79.50 2022-01-02
# 84   S59175740        1300.0            NaN    570.76 2021-12-17
# 98   S17546649       20000.0            NaN    957.76 2021-12-05
# 99   S17423978       10000.0            NaN  20957.76 2021-12-05
# 100  S17402284       10000.0            NaN  30957.76 2021-12-05
# 102  S84372496        1377.0            NaN    957.76 2021-12-03

# %%
df4=df3[((df3["Tran Date"].dt.month==1) | (df3["Tran Date"].dt.month==12)) & (df3['Debit amount']>1000)]
df4
# Out:
#        Tran ID  Debit amount  Credit amount   Balance  Tran Date
# 23   S48541898        1500.0            NaN     91.78 2022-01-16
# 44   S87434111        1970.0            NaN   1337.78 2022-01-08
# 54   S62374883        1076.6            NaN     79.50 2022-01-02
# 84   S59175740        1300.0            NaN    570.76 2021-12-17
# 98   S17546649       20000.0            NaN    957.76 2021-12-05
# 99   S17423978       10000.0            NaN  20957.76 2021-12-05
# 100  S17402284       10000.0            NaN  30957.76 2021-12-05
# 102  S84372496        1377.0            NaN    957.76 2021-12-03

# %%
df3[((df3["Tran Date"].dt.month==1) |(df3["Tran Date"].dt.month==12)) & (df3['Credit amount']>1000)]
# Out:
#        Tran ID  Debit amount  Credit amount   Balance  Tran Date
# 15   S67933397           NaN         2628.5   2649.28 2022-01-28
# 45   S87129184           NaN         1060.0   3307.78 2022-01-08
# 48    AA567812           NaN         2000.0   2706.78 2022-01-07
# 85   S57064906           NaN         1050.0   1870.76 2021-12-17
# 101  S17122896           NaN        40000.0  40957.76 2021-12-05
# 103  S84358518           NaN         1380.0   2334.76 2021-12-03

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style

# %%
plt.figure(figsize=(60,30))
plt.bar(df2['Tran Date'],df2['Debit amount'], label='Debit amount')
plt.bar(df2['Tran Date'],df2['Credit amount'], label='Credit amount', color='orange')
plt.legend(fontsize= 'xx-large')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Three month transaction')
plt.show()

# %%
plt.figure(figsize=(60,30))
plt.bar(df2['Tran Date'],df2['Debit amount'], label='Debit amount')

plt.legend(fontsize= 'xx-large')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Three month transaction')
plt.show()

# %%
plt.figure(figsize=(60,30))

plt.bar(df2['Tran Date'],df2['Credit amount'], label='Credit amount', color='orange')
plt.legend(fontsize= 'xx-large')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Three month transaction')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.bar(df4['Tran Date'], df4['Debit amount'], label='Debit amount', color='m')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('One month debit above 1000 ')
plt.show()

# %%
df3[(df3["Tran Date"].dt.day==1) ]
# Out:
#        Tran ID  Debit amount  Credit amount  Balance  Tran Date
# 57   S32439453          50.0            NaN    56.10 2022-01-01
# 106  S30798263           NaN           20.0   994.76 2021-12-01
# 107  S30782612          48.0            NaN   974.76 2021-12-01
# 146  S90499858         220.0            NaN    24.76 2021-11-01

# %%
df5=df3[(df3["Tran Date"].dt.day==1) ]
df5
# Out:
#        Tran ID  Debit amount  Credit amount  Balance  Tran Date
# 57   S32439453          50.0            NaN    56.10 2022-01-01
# 106  S30798263           NaN           20.0   994.76 2021-12-01
# 107  S30782612          48.0            NaN   974.76 2021-12-01
# 146  S90499858         220.0            NaN    24.76 2021-11-01

# %%
plt.figure(figsize=(12,5))
plt.bar(df5['Tran Date'], df5['Debit amount'], label='Debit amount', color='green')
plt.bar(df5['Tran Date'], df5['Credit amount'], label='Credit amount', color='yellow')
plt.legend(fontsize= 'large')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('One day Debit & Credit')
plt.show()

# %%
df7=df3[((df3["Tran Date"].dt.month==1) |(df3["Tran Date"].dt.month==12)) &(df3['Credit amount']>1000)]
df7
# Out:
#        Tran ID  Debit amount  Credit amount   Balance  Tran Date
# 15   S67933397           NaN         2628.5   2649.28 2022-01-28
# 45   S87129184           NaN         1060.0   3307.78 2022-01-08
# 48    AA567812           NaN         2000.0   2706.78 2022-01-07
# 85   S57064906           NaN         1050.0   1870.76 2021-12-17
# 101  S17122896           NaN        40000.0  40957.76 2021-12-05
# 103  S84358518           NaN         1380.0   2334.76 2021-12-03

# %%
plt.figure(figsize=(10,5))
plt.bar(df7['Tran Date'], df7['Credit amount'], label='Credit amount', color='purple')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('One month Credit above 1000 ')
plt.show()

# %%
df3[(df3["Tran Date"].dt.year==2022)]
# Out:
#       Tran ID  Debit amount  Credit amount  Balance  Tran Date
# 0   S50143038          15.0            NaN  1934.28 2022-01-30
# 1   S46872325         950.0            NaN  1949.28 2022-01-30
# 2   S46709981           NaN         200.00  2899.28 2022-01-30
# 3   S46535807           NaN         130.00  2699.28 2022-01-30
# 4   S45889789           NaN         150.00  2569.28 2022-01-30
# 5   S45074785           NaN          70.00  2419.28 2022-01-30
# 6   S45056761           NaN          68.00  2349.28 2022-01-30
# 7   S45036680         340.0            NaN  2281.28 2022-01-30
# 8   S44360522           NaN         150.00  2621.28 2022-01-30
# 9   S44334060           NaN         150.00  2471.28 2022-01-30
# 10  S44332552           NaN         150.00  2321.28 2022-01-30
# 11  S12005106          15.0            NaN  2171.28 2022-01-29
# 12  S93517453         350.0            NaN  2186.28 2022-01-28
# 13  S74784331          14.0            NaN  2536.28 2022-01-28
# ...

# %%
df8=df3[(df3["Tran Date"].dt.year==2022)]
df8
# Out:
#       Tran ID  Debit amount  Credit amount  Balance  Tran Date
# 0   S50143038          15.0            NaN  1934.28 2022-01-30
# 1   S46872325         950.0            NaN  1949.28 2022-01-30
# 2   S46709981           NaN         200.00  2899.28 2022-01-30
# 3   S46535807           NaN         130.00  2699.28 2022-01-30
# 4   S45889789           NaN         150.00  2569.28 2022-01-30
# 5   S45074785           NaN          70.00  2419.28 2022-01-30
# 6   S45056761           NaN          68.00  2349.28 2022-01-30
# 7   S45036680         340.0            NaN  2281.28 2022-01-30
# 8   S44360522           NaN         150.00  2621.28 2022-01-30
# 9   S44334060           NaN         150.00  2471.28 2022-01-30
# 10  S44332552           NaN         150.00  2321.28 2022-01-30
# 11  S12005106          15.0            NaN  2171.28 2022-01-29
# 12  S93517453         350.0            NaN  2186.28 2022-01-28
# 13  S74784331          14.0            NaN  2536.28 2022-01-28
# ...

# %%
plt.figure(figsize=(12,5))
plt.bar(df8['Tran Date'], df8['Debit amount'], label='Debit amount', color='red')
plt.bar(df8['Tran Date'], df8['Credit amount'], label='Credit amount', color='c')
plt.legend(title='Transaction Sign', loc = 'upper left', fontsize='medium',title_fontsize='medium')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Transaction of Jan. 2022')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
ax.plot(df8['Tran Date'], df8['Debit amount'], label='Debit amount',color='green',linewidth=4,linestyle='-',mec='m',mew=0.9,ms='10',alpha=0.9,markerfacecolor='red')
ax.plot(df8['Tran Date'], df8['Credit amount'], label='Credit amount',color='m',linewidth=4,linestyle='-',mec='m',mew=0.9,ms='10',alpha=0.9,markerfacecolor='yellow')
ax.legend(title='Transaction Sign', loc = 'upper right', fontsize='large',title_fontsize='large', bbox_to_anchor=(1.0,-0.01,-0.01,1))
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Transaction of Jan. 2022')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot([],[],label='Debit',color='c',linewidth=5)
plt.plot([],[],label='Credit',color='m',linewidth=5)

plt.stackplot(df8['Tran Date'], df8['Debit amount'],colors=['c'])
plt.stackplot(df8['Tran Date'], df8['Credit amount'],colors=['m'])
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Transaction of Jan. 2022')
plt.legend(title='Transaction Sign', loc = 'upper right', fontsize='large',title_fontsize='large', bbox_to_anchor=(1.0,-0.01,-0.01,1))
plt.show()

# %%
df3[((df3["Tran Date"].dt.month==1) | (df3["Tran Date"].dt.month==12)) & (df3['Debit amount']<1000)]
# Out:
#        Tran ID  Debit amount  Credit amount  Balance  Tran Date
# 0    S50143038         15.00            NaN  1934.28 2022-01-30
# 1    S46872325        950.00            NaN  1949.28 2022-01-30
# 7    S45036680        340.00            NaN  2281.28 2022-01-30
# 11   S12005106         15.00            NaN  2171.28 2022-01-29
# 12   S93517453        350.00            NaN  2186.28 2022-01-28
# 13   S74784331         14.00            NaN  2536.28 2022-01-28
# 14   S73665206         99.00            NaN  2550.28 2022-01-28
# 16   S85004492         11.00            NaN    20.78 2022-01-24
# 17   S72081135        140.00            NaN    31.78 2022-01-23
# 18    C2883965         66.00            NaN   171.78 2022-01-23
# 19   S56637886         15.00            NaN   237.78 2022-01-22
# 21   S77289420        389.00            NaN   102.78 2022-01-18
# 25   S43073293        150.00            NaN  1091.78 2022-01-16
# 30   S10808186        600.00            NaN   491.78 2022-01-14
# ...

# %%
df9= df3[((df3["Tran Date"].dt.month==1) | (df3["Tran Date"].dt.month==12)) & (df3['Debit amount']<1000)]
df9
# Out:
#        Tran ID  Debit amount  Credit amount  Balance  Tran Date
# 0    S50143038         15.00            NaN  1934.28 2022-01-30
# 1    S46872325        950.00            NaN  1949.28 2022-01-30
# 7    S45036680        340.00            NaN  2281.28 2022-01-30
# 11   S12005106         15.00            NaN  2171.28 2022-01-29
# 12   S93517453        350.00            NaN  2186.28 2022-01-28
# 13   S74784331         14.00            NaN  2536.28 2022-01-28
# 14   S73665206         99.00            NaN  2550.28 2022-01-28
# 16   S85004492         11.00            NaN    20.78 2022-01-24
# 17   S72081135        140.00            NaN    31.78 2022-01-23
# 18    C2883965         66.00            NaN   171.78 2022-01-23
# 19   S56637886         15.00            NaN   237.78 2022-01-22
# 21   S77289420        389.00            NaN   102.78 2022-01-18
# 25   S43073293        150.00            NaN  1091.78 2022-01-16
# 30   S10808186        600.00            NaN   491.78 2022-01-14
# ...

# %%
plt.figure(figsize=(11,5))
plt.bar(df9['Tran Date'], df9['Debit amount'], label='Debit amount', color='pink')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('One month debit below 1000 ')
plt.show()

# %%
df3[((df3["Tran Date"].dt.month==1) |(df3["Tran Date"].dt.month==12)) & (df3['Credit amount']<1000)]
# Out:
#        Tran ID  Debit amount  Credit amount  Balance  Tran Date
# 2    S46709981           NaN         200.00  2899.28 2022-01-30
# 3    S46535807           NaN         130.00  2699.28 2022-01-30
# 4    S45889789           NaN         150.00  2569.28 2022-01-30
# 5    S45074785           NaN          70.00  2419.28 2022-01-30
# 6    S45056761           NaN          68.00  2349.28 2022-01-30
# 8    S44360522           NaN         150.00  2621.28 2022-01-30
# 9    S44334060           NaN         150.00  2471.28 2022-01-30
# 10   S44332552           NaN         150.00  2321.28 2022-01-30
# 20   S44599354           NaN         150.00   252.78 2022-01-21
# 22   S77071805           NaN         400.00   491.78 2022-01-18
# 24   S48503426           NaN         500.00  1591.78 2022-01-16
# 26   S42809508           NaN         180.00  1241.78 2022-01-16
# 27   S42797137           NaN         200.00  1061.78 2022-01-16
# 28   S42794643           NaN         200.00   861.78 2022-01-16
# ...

# %%
df10=df3[((df3["Tran Date"].dt.month==1) |(df3["Tran Date"].dt.month==12)) & (df3['Credit amount']<1000)]
df10
# Out:
#        Tran ID  Debit amount  Credit amount  Balance  Tran Date
# 2    S46709981           NaN         200.00  2899.28 2022-01-30
# 3    S46535807           NaN         130.00  2699.28 2022-01-30
# 4    S45889789           NaN         150.00  2569.28 2022-01-30
# 5    S45074785           NaN          70.00  2419.28 2022-01-30
# 6    S45056761           NaN          68.00  2349.28 2022-01-30
# 8    S44360522           NaN         150.00  2621.28 2022-01-30
# 9    S44334060           NaN         150.00  2471.28 2022-01-30
# 10   S44332552           NaN         150.00  2321.28 2022-01-30
# 20   S44599354           NaN         150.00   252.78 2022-01-21
# 22   S77071805           NaN         400.00   491.78 2022-01-18
# 24   S48503426           NaN         500.00  1591.78 2022-01-16
# 26   S42809508           NaN         180.00  1241.78 2022-01-16
# 27   S42797137           NaN         200.00  1061.78 2022-01-16
# 28   S42794643           NaN         200.00   861.78 2022-01-16
# ...

# %%
plt.figure(figsize=(11,5))
plt.bar(df10['Tran Date'], df10['Credit amount'], label='Credit amount', color='lightblue')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('One month Credit below 1000 ')
plt.show()

# %% [markdown]
# # -->> Bank Statement of Devavrat Joshi

# %%
pdf_path1 = "D://Devvrat Joshi Bank Statement.pdf"

# %%
dff = tb.read_pdf("D://Devvrat Joshi Bank Statement.pdf",stream=True,pages='all')
dff
# Out:
# [           Date                          Narration Cheque/Ref. No.  \
#  0           NaN                                                NaN
#  1   16 Feb 2022  Chq Paid-MICR CTS-MU- 9,763.93SILVER OAK COLLE...
#  2   10 Feb 2022                     CASH DEP BOPAL, 48,763.93AHMED
#  3   01 Jan 2022                        Credit Interest Capitalised
#  4           NaN                                 FOR SURE COVER FD-
#  5           NaN                                 DEVVRAT JOSHI Dr -
#  6   13 Dec 2021                               03052990000029 - CHQ
#  7           NaN                                TRANSITORY AC BOPAL
#  8           NaN                                             BRANCH
#  9   07 Dec 2021    FD Redeem Principal 306,788.93-03054470020563-9
#  10  07 Dec 2021     FD Redeem Interest 210,380.17-03054470020563-9
#  11  07 Dec 2021     FD Redeem Interest 209,526.17-03054470027075-9
#  12  07 Dec 2021    FD Redeem Principal 207,529.17-03054470027075-9
# ...

# %%
#tb.convert_into(pdf_path1,"D_joshi_bank_stat.csv",output_format="csv",pages='all')

# %%
test3= pd.read_csv("C://Users//utsav//D_joshi_bank_stat.csv")
test3
# Out:
#     View / Download Account Statement\rPrint This Pag  \
# 0                                                 NaN
# 1   [ Select Another Account / Period ]Page 1 of 1...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
test3.drop([0,1,21],axis=0,inplace=True)

# %%
test3
# Out:
#    View / Download Account Statement\rPrint This Pag   Unnamed: 1  \
# 2                                                NaN         Date
# 3                                                NaN  16 Feb 2022
# 4                                                NaN  10 Feb 2022
# 5                                                NaN  01 Jan 2022
# 6                                                NaN  13 Dec 2021
# 7                                                NaN  07 Dec 2021
# 8                                                NaN  07 Dec 2021
# 9                                                NaN  07 Dec 2021
# 10                                               NaN  07 Dec 2021
# 11                                               NaN  07 Dec 2021
# 12                                               NaN  07 Dec 2021
# 13                                               NaN  07 Dec 2021
# 14                                               NaN  07 Dec 2021
# ...

# %%
test3.drop(["View / Download Account Statement\rPrint This Pag"], axis = 1, inplace=True)

# %%
test3
# Out:
#      Unnamed: 1                                         Unnamed: 2  \
# 2          Date                                          Narration
# 3   16 Feb 2022          Chq Paid-MICR CTS-MU-\rSILVER OAK COLLEGE
# 4   10 Feb 2022                             CASH DEP BOPAL,\rAHMED
# 5   01 Jan 2022                        Credit Interest Capitalised
# 6   13 Dec 2021  FOR SURE COVER FD-\rDEVVRAT JOSHI Dr -\r030529...
# 7   07 Dec 2021             FD Redeem Principal\r-03054470020563-9
# 8   07 Dec 2021              FD Redeem Interest\r-03054470020563-9
# 9   07 Dec 2021              FD Redeem Interest\r-03054470027075-9
# 10  07 Dec 2021             FD Redeem Principal\r-03054470027075-9
# 11  07 Dec 2021             FD Redeem Principal\r-50300051450320-8
# 12  07 Dec 2021              FD Redeem Interest\r-50300051450320-8
# 13  07 Dec 2021             FD Redeem Principal\r-50300571211542-1
# 14  07 Dec 2021              FD Redeem Interest\r-50300571211542-1
# ...

# %%
test3.drop(["Unnamed: 3","Unnamed: 4"], axis = 1, inplace=True)
test3
# Out:
#      Unnamed: 1                                         Unnamed: 2  \
# 2          Date                                          Narration
# 3   16 Feb 2022          Chq Paid-MICR CTS-MU-\rSILVER OAK COLLEGE
# 4   10 Feb 2022                             CASH DEP BOPAL,\rAHMED
# 5   01 Jan 2022                        Credit Interest Capitalised
# 6   13 Dec 2021  FOR SURE COVER FD-\rDEVVRAT JOSHI Dr -\r030529...
# 7   07 Dec 2021             FD Redeem Principal\r-03054470020563-9
# 8   07 Dec 2021              FD Redeem Interest\r-03054470020563-9
# 9   07 Dec 2021              FD Redeem Interest\r-03054470027075-9
# 10  07 Dec 2021             FD Redeem Principal\r-03054470027075-9
# 11  07 Dec 2021             FD Redeem Principal\r-50300051450320-8
# 12  07 Dec 2021              FD Redeem Interest\r-50300051450320-8
# 13  07 Dec 2021             FD Redeem Principal\r-50300571211542-1
# 14  07 Dec 2021              FD Redeem Interest\r-50300571211542-1
# ...

# %%
test3.columns = test3.iloc[0]
df = test3[1:]

# %%
test3
# Out:
# 2          Date                                          Narration  \
# 2          Date                                          Narration
# 3   16 Feb 2022          Chq Paid-MICR CTS-MU-\rSILVER OAK COLLEGE
# 4   10 Feb 2022                             CASH DEP BOPAL,\rAHMED
# 5   01 Jan 2022                        Credit Interest Capitalised
# 6   13 Dec 2021  FOR SURE COVER FD-\rDEVVRAT JOSHI Dr -\r030529...
# 7   07 Dec 2021             FD Redeem Principal\r-03054470020563-9
# 8   07 Dec 2021              FD Redeem Interest\r-03054470020563-9
# 9   07 Dec 2021              FD Redeem Interest\r-03054470027075-9
# 10  07 Dec 2021             FD Redeem Principal\r-03054470027075-9
# 11  07 Dec 2021             FD Redeem Principal\r-50300051450320-8
# 12  07 Dec 2021              FD Redeem Interest\r-50300051450320-8
# 13  07 Dec 2021             FD Redeem Principal\r-50300571211542-1
# 14  07 Dec 2021              FD Redeem Interest\r-50300571211542-1
# ...

# %%
#test3.to_csv("test4.csv",index=0)

# %%
sd = pd.read_csv("test4.csv")
sd
# Out:
#            Date                                          Narration  \
# 0   16 Feb 2022          Chq Paid-MICR CTS-MU-\rSILVER OAK COLLEGE
# 1   10 Feb 2022                             CASH DEP BOPAL,\rAHMED
# 2   01 Jan 2022                        Credit Interest Capitalised
# 3   13 Dec 2021  FOR SURE COVER FD-\rDEVVRAT JOSHI Dr -\r030529...
# 4   07 Dec 2021             FD Redeem Principal\r-03054470020563-9
# 5   07 Dec 2021              FD Redeem Interest\r-03054470020563-9
# 6   07 Dec 2021              FD Redeem Interest\r-03054470027075-9
# 7   07 Dec 2021             FD Redeem Principal\r-03054470027075-9
# 8   07 Dec 2021             FD Redeem Principal\r-50300051450320-8
# 9   07 Dec 2021              FD Redeem Interest\r-50300051450320-8
# 10  07 Dec 2021             FD Redeem Principal\r-50300571211542-1
# 11  07 Dec 2021              FD Redeem Interest\r-50300571211542-1
# 12  25 Oct 2021          Chq Paid-TRANSFER IN-\rHDFC STANDARD LIFE
# ...

# %%
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             18 non-null     object
#  1   Narration        18 non-null     object
#  2   Withdrawal       3 non-null      object
#  3   Deposit          15 non-null     object
# Balance  18 non-null     object
# dtypes: object(5)
# memory usage: 848.0+ bytes

# %%
sd.dtypes
# Out:
# Date                object
# Narration           object
# Withdrawal          object
# Deposit             object
# Closing\rBalance    object
# dtype: object

# %%
sd['Withdrawal']=sd['Withdrawal'].str.replace(',','').astype('float')

# %%
sd['Deposit']=sd['Deposit'].str.replace(',','').astype('float')

# %%
sd['Closing\rBalance']=sd['Closing\rBalance'].str.replace(',','').astype('float')

# %%
sd.shape
# Out:
# (18, 5)

# %%
sd["Date"] = pd.to_datetime(sd['Date'],dayfirst=True)

# %%
sd["Date"]
# Out:
# 0    2022-02-16
# 1    2022-02-10
# 2    2022-01-01
# 3    2021-12-13
# 4    2021-12-07
# 5    2021-12-07
# 6    2021-12-07
# 7    2021-12-07
# 8    2021-12-07
# 9    2021-12-07
# 10   2021-12-07
# 11   2021-12-07
# 12   2021-10-25
# 13   2021-08-27
# 14   2021-07-01
# 15   2021-04-01
# 16   2021-01-01
# 17   2020-11-30
# Name: Date, dtype: datetime64[ns]

# %%
sd
# Out:
#          Date                                          Narration  Withdrawal  \
# 0  2022-02-16          Chq Paid-MICR CTS-MU-\rSILVER OAK COLLEGE     39000.0
# 1  2022-02-10                             CASH DEP BOPAL,\rAHMED         NaN
# 2  2022-01-01                        Credit Interest Capitalised         NaN
# 3  2021-12-13  FOR SURE COVER FD-\rDEVVRAT JOSHI Dr -\r030529...    300000.0
# 4  2021-12-07             FD Redeem Principal\r-03054470020563-9         NaN
# 5  2021-12-07              FD Redeem Interest\r-03054470020563-9         NaN
# 6  2021-12-07              FD Redeem Interest\r-03054470027075-9         NaN
# 7  2021-12-07             FD Redeem Principal\r-03054470027075-9         NaN
# 8  2021-12-07             FD Redeem Principal\r-50300051450320-8         NaN
# 9  2021-12-07              FD Redeem Interest\r-50300051450320-8         NaN
# 10 2021-12-07             FD Redeem Principal\r-50300571211542-1         NaN
# ...

# %%
sd.dtypes
# Out:
# Date                datetime64[ns]
# Narration                   object
# Withdrawal                 float64
# Deposit                    float64
# Closing\rBalance           float64
# dtype: object

# %% [markdown]
# ## --> Analysis on Withdrawal

# %%
dff1=sd[((sd["Date"].dt.month==2) | (sd["Date"].dt.month==10) | (sd["Date"].dt.month==12)) & (sd['Withdrawal']>1000)]
dff1
# Out:
#          Date                                          Narration  Withdrawal  \
# 0  2022-02-16          Chq Paid-MICR CTS-MU-\rSILVER OAK COLLEGE     39000.0
# 3  2021-12-13  FOR SURE COVER FD-\rDEVVRAT JOSHI Dr -\r030529...    300000.0
# 12 2021-10-25          Chq Paid-TRANSFER IN-\rHDFC STANDARD LIFE    818000.0
#
#     Deposit  Closing\rBalance
# 0       NaN           9763.93
# 3       NaN           6788.93
# 12      NaN          36199.36

# %%
dff2=sd[((sd["Date"].dt.month==2) | (sd["Date"].dt.month==10) | (sd["Date"].dt.month==12)) & (sd['Withdrawal']>100000)]
dff2
# Out:
#          Date                                          Narration  Withdrawal  \
# 3  2021-12-13  FOR SURE COVER FD-\rDEVVRAT JOSHI Dr -\r030529...    300000.0
# 12 2021-10-25          Chq Paid-TRANSFER IN-\rHDFC STANDARD LIFE    818000.0
#
#     Deposit  Closing\rBalance
# 3       NaN           6788.93
# 12      NaN          36199.36

# %%
dff3=sd[(sd['Withdrawal']<1000)]
dff3
# Out:
# Empty DataFrame
# Columns: [Date, Narration, Withdrawal, Deposit, Closing
# Balance]
# Index: []

# %% [markdown]
# ## --> Analysis on Deposit

# %%
dff4=sd[((sd["Date"].dt.month==2) | (sd["Date"].dt.month==10) | (sd["Date"].dt.month==12)) & (sd['Deposit']>1000)]
dff4
# Out:
#          Date                               Narration  Withdrawal   Deposit  \
# 1  2022-02-10                  CASH DEP BOPAL,\rAHMED         NaN  40000.00
# 4  2021-12-07  FD Redeem Principal\r-03054470020563-9         NaN  96408.76
# 6  2021-12-07   FD Redeem Interest\r-03054470027075-9         NaN   1997.00
# 7  2021-12-07  FD Redeem Principal\r-03054470027075-9         NaN  89819.14
# 8  2021-12-07  FD Redeem Principal\r-50300051450320-8         NaN  56268.00
# 10 2021-12-07  FD Redeem Principal\r-50300571211542-1         NaN  24699.67
#
#     Closing\rBalance
# 1           48763.93
# 4          306788.93
# 6          209526.17
# 7          207529.17
# 8          117710.03
# 10          60912.03

# %%
dff5=sd[((sd["Date"].dt.month==2) | (sd["Date"].dt.month==10) | (sd["Date"].dt.month==12)) & (sd['Deposit']<1000)]
dff5
# Out:
#          Date                              Narration  Withdrawal  Deposit  \
# 5  2021-12-07  FD Redeem Interest\r-03054470020563-9         NaN    854.0
# 9  2021-12-07  FD Redeem Interest\r-50300051450320-8         NaN    530.0
# 11 2021-12-07  FD Redeem Interest\r-50300571211542-1         NaN     13.0
#
#     Closing\rBalance
# 5          210380.17
# 9           61442.03
# 11          36212.36

# %%
dff6=sd[(sd['Deposit']>100000)]
dff6
# Out:
#          Date                                          Narration  Withdrawal  \
# 13 2021-08-27  RTGS Cr-UTIB0000003-\rPARASHER K JOSHI-\rDEVVR...         NaN
# 17 2020-11-30                            Balance brought forward         NaN
#
#       Deposit  Closing\rBalance
# 13  400000.00         849648.36
# 17  439717.36         439717.36

# %% [markdown]
# ## -->Day wise Analysis

# %%
dff7=sd[(sd["Date"].dt.day==1)]
dff7
# Out:
#          Date                    Narration  Withdrawal  Deposit  \
# 2  2022-01-01  Credit Interest Capitalised         NaN   1975.0
# 14 2021-07-01  Credit Interest Capitalised         NaN   3338.0
# 15 2021-04-01  Credit Interest Capitalised         NaN   3277.0
# 16 2021-01-01  Credit Interest Capitalised         NaN   3316.0
#
#     Closing\rBalance
# 2            8763.93
# 14         449648.36
# 15         446310.36
# 16         443033.36

# %%
dff8=sd[(sd["Date"].dt.day==7)]
dff8
# Out:
#          Date                               Narration  Withdrawal   Deposit  \
# 4  2021-12-07  FD Redeem Principal\r-03054470020563-9         NaN  96408.76
# 5  2021-12-07   FD Redeem Interest\r-03054470020563-9         NaN    854.00
# 6  2021-12-07   FD Redeem Interest\r-03054470027075-9         NaN   1997.00
# 7  2021-12-07  FD Redeem Principal\r-03054470027075-9         NaN  89819.14
# 8  2021-12-07  FD Redeem Principal\r-50300051450320-8         NaN  56268.00
# 9  2021-12-07   FD Redeem Interest\r-50300051450320-8         NaN    530.00
# 10 2021-12-07  FD Redeem Principal\r-50300571211542-1         NaN  24699.67
# 11 2021-12-07   FD Redeem Interest\r-50300571211542-1         NaN     13.00
#
#     Closing\rBalance
# 4          306788.93
# 5          210380.17
# 6          209526.17
# 7          207529.17
# 8          117710.03
# 9           61442.03
# 10          60912.03
# 11          36212.36

# %%
dff9=sd[(sd["Date"].dt.day==7) & (sd['Deposit']>10000)]
dff9
# Out:
#          Date                               Narration  Withdrawal   Deposit  \
# 4  2021-12-07  FD Redeem Principal\r-03054470020563-9         NaN  96408.76
# 7  2021-12-07  FD Redeem Principal\r-03054470027075-9         NaN  89819.14
# 8  2021-12-07  FD Redeem Principal\r-50300051450320-8         NaN  56268.00
# 10 2021-12-07  FD Redeem Principal\r-50300571211542-1         NaN  24699.67
#
#     Closing\rBalance
# 4          306788.93
# 7          207529.17
# 8          117710.03
# 10          60912.03

# %%
dff10=sd[(sd['Closing\rBalance']>200000)]
dff10
# Out:
#          Date                                          Narration  Withdrawal  \
# 4  2021-12-07             FD Redeem Principal\r-03054470020563-9         NaN
# 5  2021-12-07              FD Redeem Interest\r-03054470020563-9         NaN
# 6  2021-12-07              FD Redeem Interest\r-03054470027075-9         NaN
# 7  2021-12-07             FD Redeem Principal\r-03054470027075-9         NaN
# 13 2021-08-27  RTGS Cr-UTIB0000003-\rPARASHER K JOSHI-\rDEVVR...         NaN
# 14 2021-07-01                        Credit Interest Capitalised         NaN
# 15 2021-04-01                        Credit Interest Capitalised         NaN
# 16 2021-01-01                        Credit Interest Capitalised         NaN
# 17 2020-11-30                            Balance brought forward         NaN
#
#       Deposit  Closing\rBalance
# 4    96408.76         306788.93
# 5      854.00         210380.17
# 6     1997.00         209526.17
# 7    89819.14         207529.17
# 13  400000.00         849648.36
# ...

# %%
dff11=sd[(sd["Date"].dt.year==2021) | (sd["Date"].dt.year==2022)]
dff11
# Out:
#          Date                                          Narration  Withdrawal  \
# 0  2022-02-16          Chq Paid-MICR CTS-MU-\rSILVER OAK COLLEGE     39000.0
# 1  2022-02-10                             CASH DEP BOPAL,\rAHMED         NaN
# 2  2022-01-01                        Credit Interest Capitalised         NaN
# 3  2021-12-13  FOR SURE COVER FD-\rDEVVRAT JOSHI Dr -\r030529...    300000.0
# 4  2021-12-07             FD Redeem Principal\r-03054470020563-9         NaN
# 5  2021-12-07              FD Redeem Interest\r-03054470020563-9         NaN
# 6  2021-12-07              FD Redeem Interest\r-03054470027075-9         NaN
# 7  2021-12-07             FD Redeem Principal\r-03054470027075-9         NaN
# 8  2021-12-07             FD Redeem Principal\r-50300051450320-8         NaN
# 9  2021-12-07              FD Redeem Interest\r-50300051450320-8         NaN
# 10 2021-12-07             FD Redeem Principal\r-50300571211542-1         NaN
# ...

# %% [markdown]
# ## --> Data Visualization

# %%
plt.figure(figsize=(10,5)) 
plt.bar(sd['Date'],sd['Withdrawal'], label='Debit amount', width=15, color='r')
plt.bar(sd['Date'],sd['Deposit'], label='Credit amount', width=10)
plt.legend(title='Transaction Sign', loc = 'upper right', fontsize='medium',title_fontsize='medium')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('One year transaction of Withdrawals & Deposits')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.bar(sd['Date'],sd['Withdrawal'], label='Debit amount', width=3, color='r')

plt.legend(title='Transaction Sign', loc = 'upper right', fontsize= 'medium')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('One year transaction of Withdrawals')
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.bar(sd['Date'],sd['Deposit'], label='Credit amount', color='g', width=15)
plt.legend(title='Transaction Sign', loc = 'upper right', fontsize= 'medium')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('One year transaction of Deposits')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.bar(dff1['Date'],dff1['Withdrawal'], label='Debit amount', width=5, color='b')

plt.legend(title='Transaction Sign', loc = 'upper right', fontsize= 'medium')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Transaction of Withdrawals & above 1000')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.bar(dff2['Date'],dff2['Withdrawal'], label='Debit amount', width=1, color='m', edgecolor='k')

plt.legend(title='Transaction Sign', loc = 'upper right', fontsize= 'medium')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Transaction of Withdrawals & above 1 Lakh')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.bar(dff3['Date'],dff3['Withdrawal'], label='Debit amount', width=1, color='black')

plt.legend(title='Transaction Sign', loc = 'upper right', fontsize= 'medium')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Transaction of Withdrawals & below 1000')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.bar(dff4['Date'],dff4['Deposit'], label='Credit amount', width=2, color='Purple')

plt.legend(title='Transaction Sign', loc = 'upper right', fontsize= 'medium')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Transaction of Deposits & above 1000')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.bar(dff5['Date'],dff5['Deposit'], label='Credit amount',color='w', edgecolor='m')

plt.legend(title='Transaction Sign', loc = 'upper right', fontsize='large',title_fontsize='large', bbox_to_anchor=(1.0,-0.01,-0.01,1))
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Transaction of Deposits & below 1000')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.bar(dff6['Date'],dff6['Deposit'], label='Credit amount',color='g', edgecolor='m', width=5)

plt.legend(title='Transaction Sign', loc = 'upper center', fontsize='large',title_fontsize='large')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Transaction of Deposits & above 1 lakh')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.bar(dff7['Date'],dff7['Withdrawal'], label='Debit amount',color='g', width=5)
plt.bar(dff7['Date'],dff7['Deposit'], label='Credit amount',color='orange', width=5)
plt.legend(title='Transaction Sign', loc = 'upper right', fontsize='large',title_fontsize='large')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Transactions of the 1st day of every month')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(dff8['Date'], dff8['Withdrawal'], label='Debit amount',color='green',linewidth=10,linestyle='--')
ax.plot(dff8['Date'], dff8['Deposit'], label='Credit amount',color='lightblue',linewidth=10,linestyle='--')
ax.legend(title='Transaction Sign', fontsize='medium',title_fontsize='large', bbox_to_anchor=(1.3,-0.01,-0.01,1))
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Deposits on every weekend ')
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.bar(dff9['Date'],dff9['Withdrawal'], label='Debit amount',color='g', width=5)
plt.bar(dff9['Date'],dff9['Deposit'], label='Credit amount',color='lightblue',edgecolor='purple')
plt.legend(title='Transaction Sign', fontsize='large',title_fontsize='large', bbox_to_anchor=(1.0,-0.01,-0.01,1))
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Deposits of every weekend above 10,000')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(dff10['Date'], dff10['Closing\rBalance'], label='Closing Balance',linewidth=4,linestyle='-.', color='c')
 
ax.legend(title='Transaction Sign', loc = 'upper center', fontsize='medium',title_fontsize='large', bbox_to_anchor=(1.18,-0.01,-0.01,1))
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Closing Balance of a year')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.bar(dff11['Date'], dff11['Withdrawal'], label='Debit amount', color='purple', width=15, edgecolor='c')
plt.bar(dff11['Date'], dff11['Deposit'], label='Credit amount', color='c', width=12, edgecolor='purple')
plt.legend(title='Transaction Sign', loc = 'upper right', fontsize='medium',title_fontsize='medium')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('Transaction comparison between 2021 & 2022')
plt.show()
